# %% [markdown]
# <a href="https://colab.research.google.com/github/jueu3037-cpu/Before-GTA-6/blob/main/dia_26_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Projeto caixa eletrônico.

# Você foi contratado para desenvolver um sistema simples de caixa eletrônico.

# O sistema deverá funcionar através de um menu

# %%
# calculadora simples

# O programa receberá dois numeros e irá realizar uma das quatro operações matemáticas

opcao = ""

numero_a = 0
numero_b = 0

print (".........MENU.......")
print ("")
print ("Opção 1 - somar")
print ("Opção 2 - subtração")
print ("Opção 3 - multiplicação")
print ("Opção 4 - somar")
print (".......................")
print ("")

try:

  while opcao != 5:
    opcao = int (input("Digite a opção desejada ou 5 para sair!: "))

    if opcao < 0 and opcao > 5:
      print("digite uma opção de 1 a 5.")

    elif opcao == 1:

      numero_a = float (input("Digite um número: "))
      numero_b = float (input("Digite um número: "))

      print(f"O total da soma de {numero_a} + {numero_b} é igual : {numero_a + numero_b}")
      print("")

    elif opcao == 2:

      numero_a = float (input("Digite um número: "))
      numero_b = float (input("Digite um número: "))

      print(f"O total da subtração de {numero_a} - {numero_b} é igual : {numero_a - numero_b}")
      print("")

    elif opcao == 3:

      numero_a = float (input("Digite um número: "))
      numero_b = float (input("Digite um número: "))

      print(f"O total da multiplicação de {numero_a} x {numero_b} é igual : {numero_a * numero_b}")
      print("")

    elif opcao == 4:

      numero_a = float (input("Digite um número: "))
      numero_b = float (input("Digite um número: "))

      print(f"O total da divisão de {numero_a} / {numero_b} é igual : {numero_a / numero_b}")
      print("")

except:
  print ("digite um numero de 1 a 5.")
# Out:
# .........MENU.......
#
# Opção 1 - somar
# Opção 2 - subtração
# Opção 3 - multiplicação
# Opção 4 - somar
# .......................
#
# Digite a opção desejada ou 5 para sair!: 1
# Digite um número: 5
# Digite um número: 6
# O total da soma de 5.0 + 6.0 é igual : 11.0
#
# Digite a opção desejada ou 5 para sair!: 4
# Digite um número: 1
# Digite um número: 1
# O total da divisão de 1.0 / 1.0 é igual : 1.0
#
# digite um numero de 1 a 5.

# %%
saldo = 1000.00
executando = True

while executando:
    print("\n=== CAIXA ELETRÔNICO ===")
    print("1. Consultar Saldo")
    print("2. Depositar")
    print("3. Sacar")
    print("4. Sair")

    opcao = input("Escolha uma opção (1-4): ")

    if opcao == '1':
        print(f"\nSeu saldo atual é R$ {saldo:.2f}")

    elif opcao == '2':
        valor = float(input("\nDigite o valor do depósito: R$ "))
        if valor > 0:
            saldo += valor
            print(f"Depósito realizado com sucesso! Novo saldo: R$ {saldo:.2f}")
        else:
            print("Valor inválido para depósito.")

    elif opcao == '3':
        valor = float(input("\nDigite o valor do saque: R$ "))
        if 0 < valor <= saldo:
            saldo -= valor
            print(f"Saque realizado com sucesso! Novo saldo: R$ {saldo:.2f}")
        elif valor > saldo:
            print("Saldo insuficiente.")
        else:
            print("Valor inválido para saque.")

    elif opcao == '4':
        print("\nObrigado por utilizar nosso Caixa Eletrônico. Volte sempre!")
        executando = False

    else:
        print("\nOpção inválida! Por favor, escolha um número de 1 a 4.")
# Out:
# === CAIXA ELETRÔNICO ===
# 1. Consultar Saldo
# 2. Depositar
# 3. Sacar
# 4. Sair
# Escolha uma opção (1-4): 4
#
# Obrigado por utilizar nosso Caixa Eletrônico. Volte sempre!
