# %% [markdown]
# <a href="https://colab.research.google.com/github/jueu3037-cpu/Before-GTA-6/blob/main/31mar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# estrutura de decisões

# escrever um prograna que recebe 02 números e identifica o número maior

# entrada

numero1 = int(input("digite o primeiro número: "))
numero2 = int(input("digite o segundo número: "))

#processamento e saída

if numero1 > numero2:
  print(f"O número {numero1} é maior que o número {numero2}.")
elif numero2 > numero1:
  print(f"O número {numero2} é maior que o número {numero1}.")
else:
  print(f"Os números {numero1} e {numero2} são iguais.")
# Out:
# digite o primeiro número: 5

# %%
numero1 = int(input("digite o primeiro número: "))
numero2 = int(input("digite o segundo número: "))

# processamento e daída

if numero1 > numero2:
  print(f"O número {numero1} é maior que o número {numero2}.")

elif numero2 > numero1:
  print(f"O número {numero2} é maior que o número {numero1}.")

else:
  print(f"Os números {numero1} e {numero2} são iguais.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1666/309764503.py in <cell line: 0>()
# ----> 1 numero1 = int(input("digite o primeiro número: "))
#       2 numero2 = int(input("digite o segundo número: "))
#       3
#       4 # processamento e daída
#       5
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# escrever um programa que o usuário digita o nome e a idade:

# identificar se o usúario é criança, adolescente ou adulto.

# > 12 criança
# > 18 adolescente
# < 18 adulto

# saida (você é ....)

idade = int (input("digite sua idade: "))
nome = int (input("digite seu nome: "))


if idade < 12:
  print
# Out:
#   File "/tmp/ipykernel_1666/1627791295.py", line 21
#     print(f"o número {numero3} é maior que {número2} and {numero1}.")else:
#                                                                      ^
# SyntaxError: invalid syntax
