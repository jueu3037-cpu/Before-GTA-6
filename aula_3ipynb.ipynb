# %% [markdown]
# <a href="https://colab.research.google.com/github/jueu3037-cpu/Before-GTA-6/blob/main/aula_3ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Lado1 = 2
Lado2 = 3

# Cáuculo da área

area = Lado1 *Lado2

# cáuculo da área de um quadrado

areaquadrado = Lado1 *Lado1

# %%
print (area)
# Out:
# 6

# %%
print (areaquadrado)
# Out:
# 4

# %%
nome = "José"
idade = 14
altura = 1.7

# %%
print(f"nome : {nome}, Idade: {idade}, Altura:  {altura}")
# Out:
# nome : José, Idade: 14, Altura:  1.7

# %% [markdown]
# Aula de programação e algoritimos
